# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/Xulydachieu")
print(os.getcwd())
# Out:
# /content/gdrive/My Drive/Xulydachieu

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import cv2

# %%
from glob import iglob
faces = pd.DataFrame([])
for path in iglob('/content/gdrive/My Drive/Xulydachieu/facedatabase/s*/*.pgm'):
 img= io.imread(path)
 face = pd.Series(img.flatten(),name=path)
 faces = faces.append(face)

# %% [markdown]
# #Cau 1

# %% [markdown]
# # K = 2

# %%
from sklearn.decomposition import PCA
faces_pca = PCA(n_components=2)
faces_pca.fit(faces)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
fig, axes = plt.subplots(1,2,figsize=(9,3),
 subplot_kw={'xticks':[], 'yticks':[]},
 gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
 ax.imshow(faces_pca.components_[i].reshape(112,92),cmap="gray")

# %%
components = faces_pca.transform(faces)
projected = faces_pca.inverse_transform(components)
fig, axes = plt.subplots(10,10,figsize=(9,9), subplot_kw={'xticks':[], 'yticks':[]},
            gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
    ax.imshow(projected[i].reshape(112,92),cmap="gray")

# %% [markdown]
# # K = 5

# %%
from sklearn.decomposition import PCA
faces_pca = PCA(n_components=5)
faces_pca.fit(faces)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=5, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
fig, axes = plt.subplots(1,5,figsize=(9,3),
 subplot_kw={'xticks':[], 'yticks':[]},
 gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
 ax.imshow(faces_pca.components_[i].reshape(112,92),cmap="gray")

# %%
components = faces_pca.transform(faces)
projected = faces_pca.inverse_transform(components)
fig, axes = plt.subplots(10,10,figsize=(9,9), subplot_kw={'xticks':[], 'yticks':[]},
            gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
    ax.imshow(projected[i].reshape(112,92),cmap="gray")

# %% [markdown]
# # K = 10

# %%
from sklearn.decomposition import PCA
faces_pca = PCA(n_components=10)
faces_pca.fit(faces)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
fig, axes = plt.subplots(1,10,figsize=(9,3),
 subplot_kw={'xticks':[], 'yticks':[]},
 gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
 ax.imshow(faces_pca.components_[i].reshape(112,92),cmap="gray")

# %%
components = faces_pca.transform(faces)
projected = faces_pca.inverse_transform(components)
fig, axes = plt.subplots(10,10,figsize=(9,9), subplot_kw={'xticks':[], 'yticks':[]},
            gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
    ax.imshow(projected[i].reshape(112,92),cmap="gray")

# %% [markdown]
# # K = 15

# %%
from sklearn.decomposition import PCA
faces_pca = PCA(n_components=15)
faces_pca.fit(faces)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=15, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
fig, axes = plt.subplots(3,5,figsize=(9,3),
 subplot_kw={'xticks':[], 'yticks':[]},
 gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
 ax.imshow(faces_pca.components_[i].reshape(112,92),cmap="gray")

# %%
components = faces_pca.transform(faces)
projected = faces_pca.inverse_transform(components)
fig, axes = plt.subplots(10,10,figsize=(9,9), subplot_kw={'xticks':[], 'yticks':[]},
            gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
    ax.imshow(projected[i].reshape(112,92),cmap="gray")

# %% [markdown]
# # K = 20

# %%
from sklearn.decomposition import PCA
faces_pca = PCA(n_components=20)
faces_pca.fit(faces)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=20, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
fig, axes = plt.subplots(2,10,figsize=(9,3),
 subplot_kw={'xticks':[], 'yticks':[]},
 gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
 ax.imshow(faces_pca.components_[i].reshape(112,92),cmap="gray")

# %%
components = faces_pca.transform(faces)
projected = faces_pca.inverse_transform(components)
fig, axes = plt.subplots(10,10,figsize=(9,9), subplot_kw={'xticks':[], 'yticks':[]},
            gridspec_kw=dict(hspace=0.01, wspace=0.01))
for i, ax in enumerate(axes.flat):
    ax.imshow(projected[i].reshape(112,92),cmap="gray")

# %%
from skimage import io, color
from skimage.io import imread

img = imread('/content/gdrive/My Drive/Xulydachieu/image.jpg')
img = img.astype(np.uint8)
img = img / 255

img_gray = color.rgb2gray(img)

plt.imshow(img_gray,cmap='gray')

# %%
from sklearn.decomposition import PCA
img_pca = PCA(n_components=0.99)
img_pca.fit(img_gray)
components = img_pca.transform(img_gray)
projected = img_pca.inverse_transform(components)

# %%
def ShowImage(ImageList, nRows=1, nCols = 2, WidthSpace = 0.00, HeightSpace = 0.00):
    from matplotlib import pyplot as plt
    import matplotlib.gridspec as gridspec

    gs = gridspec.GridSpec(nRows, nCols)
    gs.update(wspace=WidthSpace, hspace = HeightSpace)
    plt.figure(figsize=(20,20))
    for i in range(len(ImageList)):
        ax1= plt.subplot(gs[i])
        ax1.set_xticklabels([])
        ax1.set_yticklabels([])
        ax1.set_aspect('equal')

        plt.subplot(nRows,nCols,i+1)

        image = ImageList[i].copy()
        if(len(image.shape)<3):
            plt.imshow(image,plt.cm.gray)
        else:
            plt.imshow(image)
        plt.title("Image " + str(i))
        plt.axis('off')
    plt.show()

# %%
ShowImage([img_gray, projected], 1, 2)
